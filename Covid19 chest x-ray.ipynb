# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d pranavraikokte/covid19-image-dataset
# Out:
# covid19-image-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/covid19-image-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()  #unzipping the file and reading it

# %%
import numpy as np 
import pandas as pd 
import random
import tensorflow as tf
import os , cv2 
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix

# %%
train= keras.utils.image_dataset_from_directory(
    directory = '/content/Covid19-dataset/train',
    labels='inferred',
    label_mode = 'categorical',
    batch_size=32,
    image_size=(256,256) 
)

test= keras.utils.image_dataset_from_directory(
    directory = '/content/Covid19-dataset/test',
    labels='inferred',
    label_mode = 'categorical',
    batch_size=32,
    image_size=(256,256)
)
# Out:
# Found 251 files belonging to 3 classes.
# Found 66 files belonging to 3 classes.

# %%
train
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# Normalize the dataset by dividing the image pixel to 255. we can also use minmax scaler to normalize the data
def process(image,label):
    image = tf.cast(image/255. ,tf.float32) #here float is to print the reminder in float form
    return image,label 

train= train.map(process)
test= test.map(process)

# %%
import keras 
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense, Input, Dropout
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout

# %%
# create CNN model

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization()) 
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(3, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  batch_normalization (BatchN  (None, 254, 254, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 125, 125, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 60, 60, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dropout (Dropout)           (None, 115200)            0
#
#  dense (Dense)               (None, 3)                 345603
#
# =================================================================
# Total params: 439,747
# Trainable params: 439,299
# Non-trainable params: 448
# _________________________________________________________________

# %%
from keras import callbacks# importing callbacks from keras to use early stopping

# %%
#early stopping helps in stopping the running of epochs, when there is a best accuracy among them.
callback= tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50)

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train,epochs= 100,validation_data=test,callbacks=[callback])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 9s 383ms/step - loss: 5.0403 - accuracy: 0.7570 - val_loss: 2.7844 - val_accuracy: 0.3030
# Epoch 2/100
# 8/8 [==============================] - 7s 245ms/step - loss: 0.7240 - accuracy: 0.9522 - val_loss: 2.5710 - val_accuracy: 0.4545
# Epoch 3/100
# 8/8 [==============================] - 5s 166ms/step - loss: 0.1285 - accuracy: 0.9880 - val_loss: 0.6968 - val_accuracy: 0.6818
# Epoch 4/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.2394 - accuracy: 0.9841 - val_loss: 1.5695 - val_accuracy: 0.5909
# Epoch 5/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.2329 - accuracy: 0.9801 - val_loss: 1.4511 - val_accuracy: 0.5758
# Epoch 6/100
# 8/8 [==============================] - 4s 162ms/step - loss: 0.3101 - accuracy: 0.9681 - val_loss: 4.8999 - val_accuracy: 0.5303
# Epoch 7/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0337 - accuracy: 0.9920 - val_loss: 6.6639 - val_accuracy: 0.5152
# Epoch 8/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.3359 - accuracy: 0.9721 - val_loss: 14.3046 - val_accuracy: 0.4242
# Epoch 9/100
# 8/8 [==============================] - 4s 167ms/step - loss: 0.3390 - accuracy: 0.9841 - val_loss: 23.5492 - val_accuracy: 0.3939
# Epoch 10/100
# 8/8 [==============================] - 4s 189ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 27.2504 - val_accuracy: 0.3939
# Epoch 11/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.1351 - accuracy: 0.9920 - val_loss: 29.2375 - val_accuracy: 0.3939
# Epoch 12/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.1660 - accuracy: 0.9880 - val_loss: 32.7876 - val_accuracy: 0.3939
# Epoch 13/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.0859 - accuracy: 0.9920 - val_loss: 39.8337 - val_accuracy: 0.3939
# Epoch 14/100
# 8/8 [==============================] - 4s 163ms/step - loss: 2.3176e-07 - accuracy: 1.0000 - val_loss: 44.1489 - val_accuracy: 0.3939
# Epoch 15/100
# 8/8 [==============================] - 4s 164ms/step - loss: 6.3020e-07 - accuracy: 1.0000 - val_loss: 47.0667 - val_accuracy: 0.3939
# Epoch 16/100
# 8/8 [==============================] - 5s 164ms/step - loss: 0.1334 - accuracy: 0.9960 - val_loss: 44.7879 - val_accuracy: 0.3939
# Epoch 17/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.0540 - accuracy: 0.9920 - val_loss: 41.4004 - val_accuracy: 0.3939
# Epoch 18/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.1308 - accuracy: 0.9880 - val_loss: 40.6079 - val_accuracy: 0.3939
# Epoch 19/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0779 - accuracy: 0.9920 - val_loss: 36.1572 - val_accuracy: 0.4091
# Epoch 20/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0896 - accuracy: 0.9761 - val_loss: 35.7365 - val_accuracy: 0.4242
# Epoch 21/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0647 - accuracy: 0.9920 - val_loss: 31.2142 - val_accuracy: 0.4848
# Epoch 22/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.1372 - accuracy: 0.9880 - val_loss: 30.5221 - val_accuracy: 0.4848
# Epoch 23/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.2736 - accuracy: 0.9801 - val_loss: 53.6125 - val_accuracy: 0.4091
# Epoch 24/100
# 8/8 [==============================] - 6s 185ms/step - loss: 1.9223e-04 - accuracy: 1.0000 - val_loss: 84.8849 - val_accuracy: 0.3939
# Epoch 25/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0966 - accuracy: 0.9920 - val_loss: 80.3897 - val_accuracy: 0.3939
# Epoch 26/100
# 8/8 [==============================] - 4s 163ms/step - loss: 6.6491e-09 - accuracy: 1.0000 - val_loss: 60.2088 - val_accuracy: 0.4091
# Epoch 27/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0542 - accuracy: 0.9960 - val_loss: 96.6511 - val_accuracy: 0.3939
# Epoch 28/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0606 - accuracy: 0.9960 - val_loss: 103.2200 - val_accuracy: 0.3939
# Epoch 29/100
# 8/8 [==============================] - 4s 189ms/step - loss: 0.0747 - accuracy: 0.9920 - val_loss: 71.7905 - val_accuracy: 0.3939
# Epoch 30/100
# 8/8 [==============================] - 4s 162ms/step - loss: 9.4986e-08 - accuracy: 1.0000 - val_loss: 38.5710 - val_accuracy: 0.4848
# Epoch 31/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0192 - accuracy: 0.9960 - val_loss: 32.7231 - val_accuracy: 0.5000
# Epoch 32/100
# 8/8 [==============================] - 4s 164ms/step - loss: 4.7494e-10 - accuracy: 1.0000 - val_loss: 28.5434 - val_accuracy: 0.5000
# Epoch 33/100
# 8/8 [==============================] - 4s 167ms/step - loss: 1.9947e-08 - accuracy: 1.0000 - val_loss: 26.1652 - val_accuracy: 0.5000
# Epoch 34/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0031 - accuracy: 0.9960 - val_loss: 24.3588 - val_accuracy: 0.5303
# Epoch 35/100
# 8/8 [==============================] - 4s 163ms/step - loss: 5.2243e-09 - accuracy: 1.0000 - val_loss: 22.8226 - val_accuracy: 0.5455
# Epoch 36/100
# 8/8 [==============================] - 4s 168ms/step - loss: 5.0958e-07 - accuracy: 1.0000 - val_loss: 21.6991 - val_accuracy: 0.5455
# Epoch 37/100
# 8/8 [==============================] - 4s 189ms/step - loss: 0.0248 - accuracy: 0.9960 - val_loss: 23.2983 - val_accuracy: 0.5303
# Epoch 38/100
# 8/8 [==============================] - 4s 165ms/step - loss: 1.4248e-09 - accuracy: 1.0000 - val_loss: 24.5868 - val_accuracy: 0.5455
# Epoch 39/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.0413 - accuracy: 0.9960 - val_loss: 27.5330 - val_accuracy: 0.5000
# Epoch 40/100
# 8/8 [==============================] - 4s 164ms/step - loss: 9.1130e-07 - accuracy: 1.0000 - val_loss: 37.2514 - val_accuracy: 0.4848
# Epoch 41/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.2495 - accuracy: 0.9960 - val_loss: 37.6375 - val_accuracy: 0.4848
# Epoch 42/100
# 8/8 [==============================] - 4s 188ms/step - loss: 4.3418e-06 - accuracy: 1.0000 - val_loss: 34.8696 - val_accuracy: 0.5000
# Epoch 43/100
# 8/8 [==============================] - 4s 190ms/step - loss: 0.2049 - accuracy: 0.9920 - val_loss: 26.9037 - val_accuracy: 0.5303
# Epoch 44/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.0042 - accuracy: 0.9960 - val_loss: 21.5274 - val_accuracy: 0.5909
# Epoch 45/100
# 8/8 [==============================] - 4s 168ms/step - loss: 0.0194 - accuracy: 0.9960 - val_loss: 14.3098 - val_accuracy: 0.6515
# Epoch 46/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.9157 - val_accuracy: 0.7727
# Epoch 47/100
# 8/8 [==============================] - 4s 169ms/step - loss: 0.0313 - accuracy: 0.9960 - val_loss: 8.6837 - val_accuracy: 0.7424
# Epoch 48/100
# 8/8 [==============================] - 4s 168ms/step - loss: 0.1342 - accuracy: 0.9960 - val_loss: 11.2414 - val_accuracy: 0.7273
# Epoch 49/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0349 - accuracy: 0.9960 - val_loss: 7.3020 - val_accuracy: 0.7879
# Epoch 50/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.0058 - accuracy: 0.9960 - val_loss: 8.3810 - val_accuracy: 0.7879
# Epoch 51/100
# 8/8 [==============================] - 4s 166ms/step - loss: 2.2322e-08 - accuracy: 1.0000 - val_loss: 5.2836 - val_accuracy: 0.8030
# Epoch 52/100
# 8/8 [==============================] - 4s 164ms/step - loss: 0.0327 - accuracy: 0.9960 - val_loss: 10.7340 - val_accuracy: 0.6970
# Epoch 53/100
# 8/8 [==============================] - 4s 189ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 24.8999 - val_accuracy: 0.5909
# Epoch 54/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 31.3164 - val_accuracy: 0.5606
# Epoch 55/100
# 8/8 [==============================] - 4s 168ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 33.2386 - val_accuracy: 0.5606
# Epoch 56/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 33.1036 - val_accuracy: 0.5606
# Epoch 57/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 32.1025 - val_accuracy: 0.5606
# Epoch 58/100
# 8/8 [==============================] - 4s 169ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 30.6569 - val_accuracy: 0.5606
# Epoch 59/100
# 8/8 [==============================] - 4s 188ms/step - loss: 1.8398e-04 - accuracy: 1.0000 - val_loss: 28.5425 - val_accuracy: 0.5758
# Epoch 60/100
# 8/8 [==============================] - 4s 170ms/step - loss: 2.4697e-08 - accuracy: 1.0000 - val_loss: 26.4491 - val_accuracy: 0.6061
# Epoch 61/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 24.8584 - val_accuracy: 0.6061
# Epoch 62/100
# 8/8 [==============================] - 4s 167ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 23.4958 - val_accuracy: 0.6364
# Epoch 63/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 22.2761 - val_accuracy: 0.6212
# Epoch 64/100
# 8/8 [==============================] - 4s 163ms/step - loss: 8.5963e-08 - accuracy: 1.0000 - val_loss: 21.1095 - val_accuracy: 0.6212
# Epoch 65/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 19.9498 - val_accuracy: 0.6212
# Epoch 66/100
# 8/8 [==============================] - 4s 190ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 18.8585 - val_accuracy: 0.6364
# Epoch 67/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 17.8027 - val_accuracy: 0.6515
# Epoch 68/100
# 8/8 [==============================] - 4s 190ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.7882 - val_accuracy: 0.6515
# Epoch 69/100
# 8/8 [==============================] - 4s 166ms/step - loss: 4.7494e-10 - accuracy: 1.0000 - val_loss: 15.7832 - val_accuracy: 0.6515
# Epoch 70/100
# 8/8 [==============================] - 4s 167ms/step - loss: 9.7361e-08 - accuracy: 1.0000 - val_loss: 14.8283 - val_accuracy: 0.6667
# Epoch 71/100
# 8/8 [==============================] - 4s 163ms/step - loss: 5.0343e-08 - accuracy: 1.0000 - val_loss: 13.9173 - val_accuracy: 0.6667
# Epoch 72/100
# 8/8 [==============================] - 4s 163ms/step - loss: 4.7494e-10 - accuracy: 1.0000 - val_loss: 13.0241 - val_accuracy: 0.6667
# Epoch 73/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 12.1728 - val_accuracy: 0.6818
# Epoch 74/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.4105 - val_accuracy: 0.6970
# Epoch 75/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.7298 - val_accuracy: 0.7273
# Epoch 76/100
# 8/8 [==============================] - 4s 163ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.1001 - val_accuracy: 0.7273
# Epoch 77/100
# 8/8 [==============================] - 4s 166ms/step - loss: 3.7471e-07 - accuracy: 1.0000 - val_loss: 9.5207 - val_accuracy: 0.7424
# Epoch 78/100
# 8/8 [==============================] - 4s 166ms/step - loss: 5.1701e-06 - accuracy: 1.0000 - val_loss: 8.9816 - val_accuracy: 0.7424
# Epoch 79/100
# 8/8 [==============================] - 4s 166ms/step - loss: 3.3246e-09 - accuracy: 1.0000 - val_loss: 8.4549 - val_accuracy: 0.7424
# Epoch 80/100
# 8/8 [==============================] - 4s 166ms/step - loss: 2.3747e-09 - accuracy: 1.0000 - val_loss: 7.9527 - val_accuracy: 0.7424
# Epoch 81/100
# 8/8 [==============================] - 4s 169ms/step - loss: 5.2243e-09 - accuracy: 1.0000 - val_loss: 7.5019 - val_accuracy: 0.7727
# Epoch 82/100
# 8/8 [==============================] - 4s 167ms/step - loss: 8.5489e-09 - accuracy: 1.0000 - val_loss: 7.1125 - val_accuracy: 0.7727
# Epoch 83/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.7508 - val_accuracy: 0.7727
# Epoch 84/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.4034 - val_accuracy: 0.7879
# Epoch 85/100
# 8/8 [==============================] - 4s 169ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.0809 - val_accuracy: 0.7879
# Epoch 86/100
# 8/8 [==============================] - 4s 166ms/step - loss: 3.3246e-09 - accuracy: 1.0000 - val_loss: 5.8204 - val_accuracy: 0.8182
# Epoch 87/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.6201 - val_accuracy: 0.8182
# Epoch 88/100
# 8/8 [==============================] - 4s 167ms/step - loss: 4.7494e-10 - accuracy: 1.0000 - val_loss: 5.4544 - val_accuracy: 0.8333
# Epoch 89/100
# 8/8 [==============================] - 4s 167ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.3167 - val_accuracy: 0.8333
# Epoch 90/100
# 8/8 [==============================] - 4s 167ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.1896 - val_accuracy: 0.8333
# Epoch 91/100
# 8/8 [==============================] - 4s 168ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.0819 - val_accuracy: 0.8333
# Epoch 92/100
# 8/8 [==============================] - 4s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.9989 - val_accuracy: 0.8333
# Epoch 93/100
# 8/8 [==============================] - 4s 164ms/step - loss: 2.1514e-07 - accuracy: 1.0000 - val_loss: 4.9276 - val_accuracy: 0.8333
# Epoch 94/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.8629 - val_accuracy: 0.8333
# Epoch 95/100
# 8/8 [==============================] - 4s 165ms/step - loss: 6.5541e-08 - accuracy: 1.0000 - val_loss: 4.8017 - val_accuracy: 0.8333
# Epoch 96/100
# 8/8 [==============================] - 4s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.7454 - val_accuracy: 0.8333

# %%
len(history.history['loss'])
# Out:
# 96

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='test')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
test_img = cv2.imread('/content/covid chest.jfif')
plt.imshow(test_img)

# %%
#resizing the img to 256,256
test_img=cv2.resize(test_img,(256,256))  
plt.imshow(test_img)

# %%
#reshaping the image
test_input=test_img.reshape((1,256,256,3)) 
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[1., 0., 0.]], dtype=float32)

# %%
np.argmax(model.predict(test_input))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 0

# %%
test_img = cv2.imread('/content/normal chest.jfif')

# %%
plt.imshow(test_img)

# %%
 #resizing the img to 256,256
test_img_scale=cv2.resize(test_img,(256,256))

# %%
plt.imshow(test_img_scale)

# %%
#reshaping the image
test_input=test_img_scale.reshape((1,256,256,3))

# %%
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[0., 1., 0.]], dtype=float32)

# %%
np.argmax(model.predict(test_input))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1
